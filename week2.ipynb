# %% [markdown]
# <a href="https://colab.research.google.com/github/silpa4h-crypto/pgm-python-sept/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
secretNumber = 7

while True:
    guess = int(input("Enter a number between 1 and 10: "))

    if guess == secretNumber:
        print("Congratulations! You guessed the number correctly!")
        break
    elif guess > secretNumber:
        print("Too high! Try again.")
    else:
        print("Too low! Try again.")
# Out:
# Enter a number between 1 and 10: 5
# Too low! Try again.
# Enter a number between 1 and 10: 9
# Too high! Try again.
# Enter a number between 1 and 10: 7
# Congratulations! You guessed the number correctly!

# %%
# Program to find factorial of a number

n = int(input("Enter a number: "))
fact = 1

for i in range(1, n + 1):
    fact = fact * i

print("Factorial of",n,"is:",fact)
# Out:
# Enter a number: 5
# Factorial of 5 is: 120

# %%
# Facebook profile picture checker

L = int(input("Enter minimum dimension L: "))
N = int(input("Enter number of photos: "))

for i in range(N):
    W, H = map(int, input("Enter width and height: ").split())

    if W < L or H < L:
        print("UPLOAD ANOTHER")
    elif W == H:
        print("ACCEPTED")
    else:
        print("CROP IT")
# Out:
# Enter minimum dimension L: 180
# Enter number of photos: 3
# Enter width and height: 640 480
# CROP IT
# Enter width and height: 180 180
# ACCEPTED
# Enter width and height: 200 300
# CROP IT
