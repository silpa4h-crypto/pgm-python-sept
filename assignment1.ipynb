# %% [markdown]
# <a href="https://colab.research.google.com/github/silpa4h-crypto/pgm-python-sept/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Hello, World!"
print(s[0:5])
# Out:
# Hello

# %%
s = "abcdefghijk"
print(s[::2])
# Out:
# acegik

# %%
s = "abcdefghij"
print(s[::2])
# Out:
# acegi

# %%
s = "1234567890"
print(s[::2])
# Out:
# 13579

# %%
s = "Python is fun"
print(s[7:9])
# Out:
# is

# %%
s = "Programming"
print(s[3:7])
# Out:
# gram

# %%
s = "abcdefgh"
print(s[::2])
# Out:
# aceg

# %%
s = "abcdefg"
print(s[-3:])
# Out:
# efg

# %%
s = "Data Science"
print(s[-3:])
# Out:
# nce

# %%
s = "Hello"
print(s[::-1])
