# %% [markdown]
# <a href="https://colab.research.google.com/github/silpa4h-crypto/pgm-python-sept/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter a number:"))
if num>0:
  print("the number is positive")
elif num<0:
  print("the number is negative")
else:
  print("the number is zero")
# Out:
# enter a number:4
# the number is positive

# %%
total_price=float(input("enter total price:"))
if total_price>5000:

   discount= total_price*.25
   final_price =total_price-discount
elif total_price>2000:

   discount= total_price*.10
   final_price =total_price-discount
   print(f"10%discount applied.final price:{final_price}")
else:
  print(f"no discount.final price:{total_price}")
# Out:
# enter total price:2300
# 10%discount applied.final price:2070.0

# %%
def calculate_ticket_price(age, day):
    if age < 5:
        price = 0
    elif 5 <= age <= 12:
        price = 150
    elif 13 <= age <= 59:
        price = 250
    elif age >= 60:
        price = 120
    else:
        price = 0 :

    if day.lower() == "friday" and price > 0:
        price = price * 0.8
    return price

# %%
cart ={
    "milk":45,"bread":30,"eggs":60,"butter":150
}
def add_item(item,price):
    cart[item]=price
    print(f"{item} added with price {price}.")
def update_price(item,new_price):
 if item in cart:
  cart[item]=new_price
  print(f"price of {item} updated to {new_price}.")

 else:
    print(f"{item} not found in cart.")
def total_items():
  return len(cart)
def total_bill():
  return sum(cart.values())
def check_item(item):
  return item in cart

# %%
movies = ['Inception', 'Titanic', 'Avatar', 'Interstellar', 'The Dark Knight']
ratings = [9.0, 7.8, 8.2, 8.6, 9.1]


movie_ratings = dict(zip(movies, ratings))
print("Initial Dictionary:", movie_ratings)


print("\nMovies with rating above 8.5:")
for movie, rating in movie_ratings.items():
    if rating > 8.5:
        print(f"{movie}: {rating}")


movie_ratings['Titanic'] = 8.3

movie_ratings['Oppenheimer'] = 9.2
del movie_ratings['Avatar']
sorted_movies = dict(sorted(movie_ratings.items(), key=lambda x: x[1], reverse=True))

print("Sorted by ratings (descending):", sorted_movies)


highest_movie = max(movie_ratings, key=movie_ratings.get)
print(f"Highest Rated Movie: {highest_movie} ({movie_ratings[highest_movie]})")
# Out:
# Initial Dictionary: {'Inception': 9.0, 'Titanic': 7.8, 'Avatar': 8.2, 'Interstellar': 8.6, 'The Dark Knight': 9.1}
#
# Movies with rating above 8.5:
# Inception: 9.0
# Interstellar: 8.6
# The Dark Knight: 9.1
# Sorted by ratings (descending): {'Oppenheimer': 9.2, 'The Dark Knight': 9.1, 'Inception': 9.0, 'Interstellar': 8.6, 'Titanic': 8.3}
# Highest Rated Movie: Oppenheimer (9.2)

# %%
cart = {"Milk": 45,
    "Bread": 30,
    "Eggs": 60,
    "Butter": 150
}

def add_item(item, price):
    cart[item] = price
    print(f"{item} added with price {price}.")

def update_price(item, new_price):
    if item in cart:
        cart[item] = new_price
        print(f"Price of {item} updated to {new_price}.")
    else:
        print(f"{item} not found in cart.")

def remove_item(item):
    if item in cart:
        del cart[item]
        print(f"{item} removed from the cart.")
    else:
        print(f"{item} not found in cart.")

def total_items():
    return len(cart)

def total_bill():
    return sum(cart.values())

def check_item(item):
    return item in cart
